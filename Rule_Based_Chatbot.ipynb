# %% [markdown]
# <a href="https://colab.research.google.com/github/Pakhi27/Rule-Based-Chatbots/blob/main/Rule_Based_Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
# generates random numbers and allows to select a response out of the given responses
import random
# rulebots rules are already decided..

class RuleBot:

    # Potential Negative Responses
    negative_responses = ("no", "nope", "nah", "naw", "not a chance", "sorry")

    # Exit conversation Keywords
    exit_commands = ("quit", "pause", "exit", "goodbye", "bye", "later")

    # Random starter questions
    random_questions = (
        "Why are you here?",
        "Are there many humans like you?",
        "What do you consume for sustenance?",
        "Is there intelligent life on twhis planet?",
        "Does Earth have a leader?",
        "What planets have you visited?",
        "What technology do you have on this planet?"
    )
    # alien that has come on earth

    def __init__(self):
        self.alienbabble = {
            # string that ends with your planet
            'describe_planet_intent': r'.*\s*your planet.*',
            # string that has why keyword
            'answer_why_intent': r'why\sare.*',
            # string that has intellipaat
            'about_intellipat': r'.*\s*intellipaat',
            'love':r'.*\s*love'
        }

    def greet(self):
        self.name = input("What is your name?\n")
        will_help = input(
            f"Hi {self.name}, I am Rule-Bot. Will you help me learn about your planet?\n")
        if will_help in self.negative_responses:
          # exists conversation
            print("Ok, have a nice Earth day!")
            return
        self.chat()

    def make_exit(self, reply):
        for command in self.exit_commands:
            if reply == command:
                print("Okay, have a nice Earth day!")
                return True
        return False
# continue chat..
    def chat(self):
        reply = input(random.choice(self.random_questions)).lower()
        while not self.make_exit(reply):
            reply = input(self.match_reply(reply))

# Iterating throught list of items in the dictionary and matching the item,if it is there in deciding its type..
    def match_reply(self, reply):
        for key, value in self.alienbabble.items():
            intent = key
            regex_pattern = value
            found_match = re.match(regex_pattern, reply)
            if found_match and intent == 'describe_planet_intent':
                return self.describe_planet_intent()
            elif found_match and intent == 'answer_why_intent':
                return self.answer_why_intent()
            elif found_match and intent == 'about_intellipat':
                return self.about_intellipat()
            elif found_match and intent == 'love':
                return self.love()
        if not found_match:
            return self.no_match_intent()

    def describe_planet_intent(self):
      # generate response from the given 2..
        responses = ("My planet is a utopia of diverse organisms and species\n",
                     "I am from Opidipus, the capital of the Wayward Galaxies.\n")
        return random.choice(responses)

    def answer_why_intent(self):
        responses = ("come in peace\n", "I am here to collect data on your planet and its inhabitants\n",
                     "I heard the coffee is good\n")
        return random.choice(responses)

    def love(self):
        responses = ("i love you so much\n", "I will be there for you in every phase of your life\n",
                     "I want to spend my whole life with you\n")
        return random.choice(responses)

    def about_intellipat(self):
        responses = ("Intellipaat is the world's largest professional educational company\n",
                     "Intellipaat will make you learn concepts in a way you've never experienced before\n",
                     "Intellipaat is where your career and skills grow\n")
        return random.choice(responses)

    def no_match_intent(self):
        responses = ("Please tell me more.\n", "Tell me more!\n", "Why do you say that?\n",
                     "I see. Can you elaborate?\n", "Interesting. Can you tell me more?\n",
                     "I see. How do you think?\n", "Why?\n", "How do you think I feel when you say that?\n")
        return random.choice(responses)

# Create an instance of RuleBot and start the conversation
AlienBot = RuleBot()
AlienBot.greet()
# Out:
# What is your name?
# rahul trimukhe
# Hi rahul trimukhe, I am Rule-Bot. Will you help me learn about your planet?
# yes
# What do you consume for sustenance?love
# i love you so much
# love is beautiful
# I will be there for you in every phase of your life
# you are so sweet my love
# I will be there for you in every phase of your life
# love is life
# I will be there for you in every phase of your life
# all my love is for you my sweetheart
# I will be there for you in every phase of your life
# love u jaan
# I will be there for you in every phase of your life
# planet
# Tell me more!
# i want to know about your planet
# My planet is a utopia of diverse organisms and species
# oh nice! your planet is  amazing
# My planet is a utopia of diverse organisms and species
# it is full of greenery
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %% [markdown]
# Chatbot using python and NLTK

# %%
import numpy as np
import nltk
import string
import random

# %%
f = open('/content/data3.txt(amazon)','r', errors = 'ignore')
raw_doc = f.read()

# %%
raw_doc
# Out:
# '\nMain menu\n\nWikipediaThe Free Encyclopedia\nSearch Wikipedia\nSearch\nCreate account\nLog in\n\nPersonal tools\nContents hide\n(Top)\nHistory\nToggle History subsection\nProducts and services\nToggle Products and services subsection\nOperations\nToggle Operations subsection\nCorporate affairs\nToggle Corporate affairs subsection\nCriticism\nSee also\nReferences\nFurther reading\nExternal links\nAmazon (company)\n\nArticle\nTalk\nRead\nView source\nView history\n\nTools\nAppearance hide\nText\n\nSmall\n\nStandard\n\nLarge\nWidth\n\nStandard\n\nWide\nColor (beta)\n\nAutomatic\n\nLight\n\nDark\nPage semi-protected\nFrom Wikipedia, the free encyclopedia\nThis article is about the multinational technology company. For other companies, see Amazon (disambiguation) § Businesses and organizations.\nAmazon.com, Inc.\n\n\nAmazon\'s headquarters, the Doppler building\nTrade name\tAmazon\nFormerly\tCadabra, Inc. (1994–1995)\nCompany type\tPublic\nTraded as\t\nNasdaq: AMZN\nNasdaq-100 componen
# ...

# %%
raw_doc.lower() #Converting entire text to lowercase
nltk.download('punkt') #Using the Punkt tokenizer
nltk.download('wordnet') #Using the wordnet dictionary
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
sentence_tokens = nltk.sent_tokenize(raw_doc)
word_tokens = nltk.word_tokenize(raw_doc)

# %% [markdown]
# After Tokenization

# %%
word_tokens
# Out:
# ['Main',
#  'menu',
#  'WikipediaThe',
#  'Free',
#  'Encyclopedia',
#  'Search',
#  'Wikipedia',
#  'Search',
#  'Create',
#  'account',
#  'Log',
#  'in',
#  'Personal',
#  'tools',
#  'Contents',
#  'hide',
#  '(',
#  'Top',
#  ')',
#  'History',
#  'Toggle',
#  'History',
#  'subsection',
#  'Products',
#  'and',
#  'services',
#  'Toggle',
#  'Products',
#  'and',
#  'services',
#  'subsection',
#  'Operations',
#  'Toggle',
#  'Operations',
#  'subsection',
#  'Corporate',
#  'affairs',
#  'Toggle',
#  'Corporate',
#  'affairs',
#  'subsection',
#  'Criticism',
#  'See',
#  'also',
#  'References',
#  'Further',
#  'reading',
#  'External',
#  'links',
#  'Amazon',
#  '(',
#  'company',
#  ')',
#  'Article',
#  'Talk',
#  'Read',
#  'View',
#  'source',
#  'View',
#  'history',
#  'Tools',
#  'Appearance',
#  'hide',
#  'Text',
#  'Small',
#  'Standard',
#  'Large',
#  'Width',
#  'Standard',
#  'Wide',
#  'Color',
#  '(',
#  'beta',
#  ')',
#  'Automatic',
#  'Light',
# ...

# %%
sentence_tokens
# Out:
# ['\nMain menu\n\nWikipediaThe Free Encyclopedia\nSearch Wikipedia\nSearch\nCreate account\nLog in\n\nPersonal tools\nContents hide\n(Top)\nHistory\nToggle History subsection\nProducts and services\nToggle Products and services subsection\nOperations\nToggle Operations subsection\nCorporate affairs\nToggle Corporate affairs subsection\nCriticism\nSee also\nReferences\nFurther reading\nExternal links\nAmazon (company)\n\nArticle\nTalk\nRead\nView source\nView history\n\nTools\nAppearance hide\nText\n\nSmall\n\nStandard\n\nLarge\nWidth\n\nStandard\n\nWide\nColor (beta)\n\nAutomatic\n\nLight\n\nDark\nPage semi-protected\nFrom Wikipedia, the free encyclopedia\nThis article is about the multinational technology company.',
#  'For other companies, see Amazon (disambiguation) § Businesses and organizations.',
# ...

# %%
raw_doc
# Out:
# '\nMain menu\n\nWikipediaThe Free Encyclopedia\nSearch Wikipedia\nSearch\nCreate account\nLog in\n\nPersonal tools\nContents hide\n(Top)\nHistory\nToggle History subsection\nProducts and services\nToggle Products and services subsection\nOperations\nToggle Operations subsection\nCorporate affairs\nToggle Corporate affairs subsection\nCriticism\nSee also\nReferences\nFurther reading\nExternal links\nAmazon (company)\n\nArticle\nTalk\nRead\nView source\nView history\n\nTools\nAppearance hide\nText\n\nSmall\n\nStandard\n\nLarge\nWidth\n\nStandard\n\nWide\nColor (beta)\n\nAutomatic\n\nLight\n\nDark\nPage semi-protected\nFrom Wikipedia, the free encyclopedia\nThis article is about the multinational technology company. For other companies, see Amazon (disambiguation) § Businesses and organizations.\nAmazon.com, Inc.\n\n\nAmazon\'s headquarters, the Doppler building\nTrade name\tAmazon\nFormerly\tCadabra, Inc. (1994–1995)\nCompany type\tPublic\nTraded as\t\nNasdaq: AMZN\nNasdaq-100 componen
# ...

# %%
sentence_tokens[:5]
# Out:
# ['\nMain menu\n\nWikipediaThe Free Encyclopedia\nSearch Wikipedia\nSearch\nCreate account\nLog in\n\nPersonal tools\nContents hide\n(Top)\nHistory\nToggle History subsection\nProducts and services\nToggle Products and services subsection\nOperations\nToggle Operations subsection\nCorporate affairs\nToggle Corporate affairs subsection\nCriticism\nSee also\nReferences\nFurther reading\nExternal links\nAmazon (company)\n\nArticle\nTalk\nRead\nView source\nView history\n\nTools\nAppearance hide\nText\n\nSmall\n\nStandard\n\nLarge\nWidth\n\nStandard\n\nWide\nColor (beta)\n\nAutomatic\n\nLight\n\nDark\nPage semi-protected\nFrom Wikipedia, the free encyclopedia\nThis article is about the multinational technology company.',
#  'For other companies, see Amazon (disambiguation) § Businesses and organizations.',
# ...

# %%
word_tokens[:15]
# Out:
# ['Main',
#  'menu',
#  'WikipediaThe',
#  'Free',
#  'Encyclopedia',
#  'Search',
#  'Wikipedia',
#  'Search',
#  'Create',
#  'account',
#  'Log',
#  'in',
#  'Personal',
#  'tools',
#  'Contents']

# %%
# Lemmatization
lemmer = nltk.stem.WordNetLemmatizer()
def LemTokens (tokens):
  return [lemmer.lemmatize(token) for token in tokens]
remove_punc_dict = dict((ord(punct), None) for punct in string.punctuation)
def LemNormalize(text):
  return LemTokens(nltk.word_tokenize(text.lower().translate(remove_punc_dict)))

# %% [markdown]
# Define Greeting Functions

# %%
greet_inputs = ('hello', 'hi', 'whassup', 'how are you?','good morning','welcome')
greet_responses = ('hi', 'Hey', 'Hey There!', 'There there!!','greetings','les go')
def greet(sentence):
 for word in sentence.split():
  if word.lower() in greet_inputs:
    return random.choice(greet_responses)

# %% [markdown]
# Response Generation by the Bot

# %%
#  Tf-idf vectorizer and cosine_similarity
# cosine-similarity-compares similarity between 2 vectors
#  tf-idf-convert sentence into vectors/numbers-give importance to least occuring/rarely seen word

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
def response(user_response):
  robo1_response = ' '
  TfidfVec = TfidfVectorizer(tokenizer = LemNormalize, stop_words = 'english')
  tfidf = TfidfVec.fit_transform(sentence_tokens)
  vals = cosine_similarity(tfidf[-1], tfidf)
  idx = vals.argsort()[0][-2]
  flat = vals.flatten()
  flat.sort()
  req_tfidf = flat[-2]
  if (req_tfidf == 0):
    robo1_response = robo1_response + "I am sorry. Unable to understand you!"
    return robo1_response
  else:
    robo1_response = robo1_response + sentence_tokens[idx]
    return robo1_response

# %% [markdown]
# Defining the chatflow

# %%
flag = True
print('Hello! I am the Retrival Learning Bot. Start typing your text after greeting to talk to me. For ending convo type bye')

while (flag==True):
    user_response = input()
    user_response = user_response.lower()
    if (user_response != 'bye'):
      # to end conversation
        if (user_response == 'thank you'  or user_response=='thanks'):
            flag = False
            print('Bot: You are Welcome..')
        else:
          if(greet(user_response) != None):
            print('Bot ' + greet(user_response))
          else:
            # sentence tokens get appended with user response and for sentence tokens word tokens will be found and final word will be generated and for them response will be generated and returned to the user
            sentence_tokens.append(user_response)
            word_tokens = word_tokens + nltk.word_tokenize(user_response)
            final_words = list(set(word_tokens))
            print('Bot: ', end= '')
            print(response(user_response))
            sentence_tokens.remove(user_response)
    else:
        flag = False
        print('Bot: Goodbye!')
# Out:
# Hello! I am the Retrival Learning Bot. Start typing your text after greeting to talk to me. For ending convo type bye
# hi
# Bot Hey
# what is amazon
# Bot:  Amazon.
# in which fields amazon is engaged
# Bot:  "Field of streams: how Twitch made video games a spectator sport".
# what is amazon.com
# Bot:  Amazon.com.
# when was amazon founded
# Bot:  Amazon was founded on July 5, 1994, by Jeff Bezos in Bellevue, Washington.
# what all subsidiaries amazon has
# Bot:  [111][112][8]
#
# Other
# Other Amazon subsidiaries include:
#
# A9.com, a company focused on researching and building innovative technology; it has been a subsidiary since 2003.
# when did amazon went public
# Bot:  [23][25]
#
# Amazon went public in May 1997.
# what market amazon purxhased
# Bot:  Whole Foods Market.
# when did amazon saw large growth
# Bot:  [35]
#
# Amazon saw large growth during the COVID-19 pandemic, hiring more than 100,000 staff in the United States and Canada.
# who is the ceo of amazon
# ...
